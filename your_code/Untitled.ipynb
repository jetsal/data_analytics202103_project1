# %%
comp_word = "bird"
 
# convert String to Set
comp_word = set(comp_word)
print("\nAfter the conversion")
print("The datatype of string : " + str(type(comp_word)))
print("Contents of string : ", comp_word)

# %%
""" def main_function2():
    print("Welcome to hangman!")
    print("It was a tough choice, but I picked a word. Here it is: \n")
    print(display_word, "\n") 
    test_succes = False
    test_gameover = False
    
    while test_succes == False and test_gameover == False:
        #let player guess a letter and check whether the letter is in the word
        check_letter(player_input())
        #show a dashboard with the updated to-be-guessed word, wrong letters and pictures
        display_function(correct_letters, wrong_letters, comp_word)

        #check if the word is guessed already
        test_succes = all(letters in correct_letters for letters in comp_word)
        if test_succes == True:
            print("hooray! You've won :)")
            break
        if test_succes == False:
            print("You dont have the word yet!")
        #check if the there are too many wrong guesses
        #if len(wrong_letters) >= len(pictures):
        if len(wrong_letters) >= 2:
            test_gameover == True
            print("Too bad, you're hanged. You guessed too many wrong letters")
            break
        else: 
            test_gameover == False
            print("not game over yet!")
            
main_function2()    
   """

# %%
# """
# while penalty <= len(pictures): 
#     player_input(penalty)

# print("these are the wrongly guessed letters:", wrong_letters)
# print("those are the correct letters:", correct_letters)
# print("this is total tried letters:", tried_letters) # this doesnt work
# """

#         for i in range(len(comp_word)):
#             if unique_letters[i] not in correct_letters:
#                 print("not all letters are correct")
#                 guess_again = True
#                 break
#             else:
#                 print("seems like you've guessed this letter")
# '''    
#     check if correct_letters contains all elements in comp_word
# '''
# result =  all(letters in correct_letters  for letters in comp_word)
# if result:
#     print("Yes, correct_letters contains all elements in comp_word")    
# else :
#     print("No, correct_letters does not contains all elements in comp_word"
        
# #         word_guessed = True
# #         for i in comp_word:
#             #print("I'm here!")
#             if i in range(len(comp_word)):
#                 print("Im further along")
#                 if comp_word[i] not in correct_letters:
#                     print("going steady down the line")
#                     word_guessed = False
#                     break #should not break out of the for while true loop
#                 else:
#                     print("Well done, you guessed the word!")
#                     break #should break out of the 'while true loop', so wont ask for more letters

        #check if the are too many wrong answers:
#         if len(wrong_letters) == 2:
#             display(correct_letters, wrong_letters, comp_word)
#             print("Ouch, too many wrong guesses. This game is over!")
#             game_over = True
#             break #breaks out of the 'while true loop', so wont ask for more letters





#     while len(wrong_letters) < len(pictures)
#         check_letter(player_input())
#     else:
#         print("stop the loop!")

# print("main_function(0,0)")
# main_function(0,0)
    
# for i in range(3):
#     check_letter(player_input())
