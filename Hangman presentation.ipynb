# %% [markdown]
# # HANGMAN
#
#
#         _________________
#         ||  /           |
#         || /            |
#         ||/            (-)
#         ||            \ | /
#         ||             \-/
#         ||              |
#         ||              |
#         ||             / \
#         ||            /   \
#         ||
#         ||
#      -------------------------------
#      /////// BY JET SALOMONS ///////
#      -------------------------------
#
#
#
# <br>

# %% [markdown]
# ### Rules of the game
# The computer picks a word, and the player has to guess it - letter by letter. Until either the player guessed the word correctly, or too many false guesses are made.

# %% [markdown]
# ### Game Flow

# %% [markdown]
# ![hangman_flow.PNG](attachment:hangman_flow.PNG)

# %% [markdown]
# ### Challenges
#
#
# #### Updating issues
# <br>
# lists that should get filled in a function, were emptied each time this was called next.
# <br>
#
# #### Main-function
# <br>
# functions worked individually, but not when they have to act together in main.
# <br>
#
# #### Assuming the worst
# <br>
# thinking the problem is a big "structural" problem instead of first thinking about a typo.

# %% [markdown]
# ### Learnings
#
# Define the parameters that need updating before you define any function
# <br>
# Inputting the outcome of one function in the next
# <br>
# Check if you use the correct parameter names before you trying something else

# %% [markdown]
# ### Improvements
#
# An option that let's the player type the entire word. If wrong: game over.
# <br>
# Improve the 'play again'-loop
# <br>
# Solve why sometimes letter-input is asked before the Title of the Game is shown and sometimes it does go the correct way.
