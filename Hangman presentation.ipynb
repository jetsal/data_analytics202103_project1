# %% [markdown]
# #### HANGMAN
#         _________________
#         ||  /           |
#         || /            |
#         ||/            (-)
#         ||            \ | /
#         ||             \-/
#         ||              |
#         ||              |
#         ||             / \
#         ||            /   \
#         ||
#         ||
#      -------------------------------
#      /////// BY JET SALOMONS ///////
#      -------------------------------
# <br>

# %% [markdown]
# ### Rules of the game
# The computer picks a word, and the player has to guess it - letter by letter. Until either the player guessed the word correctly, or too many false guesses are made.

# %% [markdown]
# ### Game Flow

# %% [markdown]
# ![hangman_flow.PNG](attachment:hangman_flow.PNG)

# %% [markdown]
# ![hangman%20flow%20part1.PNG](attachment:hangman%20flow%20part1.PNG)

# %% [markdown]
# ![hangman%20flow%20part2.PNG](attachment:hangman%20flow%20part2.PNG)

# %% [markdown]
# ### Challenges
#
# 1). Unwanted list-emptying issues
# <br>
# 2). Cooperation of functions in main
# <br>
# 3). No error, but unexpected outcome
# <br>

# %% [markdown]
# ### Learnings
#
# 1). Coding stuff and shortkeys<br>
# 2). Addictive <br>
# 3). Check for typos first
# <br>

# %% [markdown]
# ### Improvements of the game
#
# 1). An option that let's the player type the **entire** word. If wrong: game over.
# <br>
# 2). Improve the 'play again'-loop
# <br>
# 3). Pretty things up in the dashboard.
# <br>
